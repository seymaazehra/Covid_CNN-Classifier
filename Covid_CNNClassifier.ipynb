# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D,GlobalAveragePooling2D
from keras.layers import Activation, Dropout, BatchNormalization, Flatten, Dense, AvgPool2D,MaxPool2D
from keras.models import Sequential, Model
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.optimizers import Adam, SGD, RMSprop
import tensorflow as tf

import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

import plotly.offline as py
import plotly.express as px

# %%
dataset = '/content/gdrive/My Drive/covid/dataset'

# %%
os.listdir(dataset)
# Out:
# ['normal', 'covid']

# %%
normal_images = []
for img_path in glob.glob(dataset + '/normal/*'):
    normal_images.append(mpimg.imread(img_path))

fig = plt.figure()
fig.suptitle('Normal Image')
plt.imshow(normal_images[0], cmap='gray')

# %%
covid_images = []
for img_path in glob.glob(dataset + '/covid/*'):
    covid_images.append(mpimg.imread(img_path))

fig = plt.figure()
fig.suptitle('covid Image')
plt.imshow(covid_images[0], cmap='gray')

# %%
Image_Width = 150
Image_Height = 150
Cannels = 3

INPUT_SHAPE = (Image_Width, Image_Height, Cannels)
NB_CLASSES = 2
EPOCHS = 45
BATCH_SIZE = 6

# %%
from keras.layers import Conv2D, MaxPooling2D,GlobalAveragePooling2D
from keras.layers import Activation, Dropout, BatchNormalization, Flatten, Dense, AvgPool2D,MaxPool2D

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=INPUT_SHAPE))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Conv2D(64,(3,3)))
model.add(Activation("relu"))
model.add(Conv2D(250,(3,3)))
model.add(Activation("relu"))
  
model.add(Conv2D(128,(3,3)))
model.add(Activation("relu"))
model.add(AvgPool2D(2,2))
model.add(Conv2D(64,(3,3)))
model.add(Activation("relu"))
model.add(AvgPool2D(2,2))

model.add(Conv2D(256,(2,2)))
model.add(Activation("relu"))
model.add(MaxPool2D(2,2))
    
model.add(Flatten())
model.add(Dense(32))
model.add(Dropout(0.25))
model.add(Dense(1))
model.add(Activation("sigmoid"))

# %%
model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])

# %%
train_images='/content/gdrive/My Drive/covid/dataset/normal'
test_images='/content/gdrive/My Drive/covid/dataset/covid'

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.25)

train_generator = train_datagen.flow_from_directory(
    dataset,
    target_size=(Image_Height, Image_Width),
    batch_size=BATCH_SIZE,
    class_mode='binary',
    subset='training')

validation_generator = train_datagen.flow_from_directory(
    dataset, 
    target_size=(Image_Height, Image_Width),
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle= False,
    subset='validation')

history = model.fit_generator(
    train_generator,
    steps_per_epoch = train_generator.samples // BATCH_SIZE,
    validation_data = validation_generator, 
    validation_steps = validation_generator.samples // BATCH_SIZE,
    epochs = EPOCHS)
# Out:
# Found 70 images belonging to 2 classes.
# Found 22 images belonging to 2 classes.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:27: UserWarning:
#
# `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/45
# 11/11 [==============================] - 26s 2s/step - loss: 0.9157 - accuracy: 0.6562 - val_loss: 0.5425 - val_accuracy: 0.8889
# Epoch 2/45
# 11/11 [==============================] - 25s 2s/step - loss: 0.6115 - accuracy: 0.7273 - val_loss: 0.3897 - val_accuracy: 0.8889
# Epoch 3/45
# 11/11 [==============================] - 23s 2s/step - loss: 0.6165 - accuracy: 0.7500 - val_loss: 0.4206 - val_accuracy: 0.8889
# Epoch 4/45
# 11/11 [==============================] - 23s 2s/step - loss: 0.7065 - accuracy: 0.6406 - val_loss: 0.4586 - val_accuracy: 0.8889
# Epoch 5/45
# 11/11 [==============================] - 23s 2s/step - loss: 0.6118 - accuracy: 0.7188 - val_loss: 0.4231 - val_accuracy: 0.8889
# Epoch 6/45
# 11/11 [==============================] - 23s 2s/step - loss: 0.6087 - accuracy: 0.7188 - val_loss: 0.4428 - val_accuracy: 0.8889
# Epoch 7/45
# 11/11 [==============================] - 23s 2s/step - loss: 0.6600 - accuracy: 0.7500 - val_loss: 0.4442 - val_accuracy: 0.8889
# Epoch 8/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.6191 - accuracy: 0.7188 - val_loss: 0.5215 - val_accuracy: 0.8889
# Epoch 9/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.8182 - accuracy: 0.6875 - val_loss: 0.3131 - val_accuracy: 0.8889
# Epoch 10/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.5962 - accuracy: 0.7188 - val_loss: 0.4687 - val_accuracy: 0.8889
# Epoch 11/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.5940 - accuracy: 0.7273 - val_loss: 0.4617 - val_accuracy: 0.8889
# Epoch 12/45
# 11/11 [==============================] - 23s 2s/step - loss: 0.5750 - accuracy: 0.7344 - val_loss: 0.4486 - val_accuracy: 0.8889
# Epoch 13/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.7660 - accuracy: 0.7344 - val_loss: 0.3637 - val_accuracy: 0.8889
# Epoch 14/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.5918 - accuracy: 0.7576 - val_loss: 0.2842 - val_accuracy: 0.8889
# Epoch 15/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.3272 - accuracy: 0.8594 - val_loss: 0.2773 - val_accuracy: 0.8889
# Epoch 16/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.3314 - accuracy: 0.8333 - val_loss: 0.1167 - val_accuracy: 1.0000
# Epoch 17/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.2465 - accuracy: 0.9375 - val_loss: 0.1682 - val_accuracy: 0.9444
# Epoch 18/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.3510 - accuracy: 0.8906 - val_loss: 0.1239 - val_accuracy: 0.9444
# Epoch 19/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.1008 - accuracy: 0.9394 - val_loss: 0.0325 - val_accuracy: 1.0000
# Epoch 20/45
# 11/11 [==============================] - 23s 2s/step - loss: 0.3335 - accuracy: 0.8906 - val_loss: 0.0959 - val_accuracy: 1.0000
# Epoch 21/45
# 11/11 [==============================] - 23s 2s/step - loss: 0.0798 - accuracy: 0.9688 - val_loss: 0.4143 - val_accuracy: 0.8333
# Epoch 22/45
# 11/11 [==============================] - 23s 2s/step - loss: 0.5022 - accuracy: 0.8750 - val_loss: 0.2102 - val_accuracy: 0.8889
# Epoch 23/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.1841 - accuracy: 0.9219 - val_loss: 0.1046 - val_accuracy: 0.9444
# Epoch 24/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.6062 - accuracy: 0.9375 - val_loss: 0.0420 - val_accuracy: 1.0000
# Epoch 25/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.1669 - accuracy: 0.9844 - val_loss: 0.8507 - val_accuracy: 0.8889
# Epoch 26/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.5467 - accuracy: 0.9219 - val_loss: 0.1408 - val_accuracy: 0.9444
# Epoch 27/45
# 11/11 [==============================] - 25s 2s/step - loss: 0.0690 - accuracy: 0.9697 - val_loss: 4.7244e-04 - val_accuracy: 1.0000
# Epoch 28/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.1540 - accuracy: 0.9531 - val_loss: 0.1530 - val_accuracy: 1.0000
# Epoch 29/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.2774 - accuracy: 0.8750 - val_loss: 0.2783 - val_accuracy: 0.8889
# Epoch 30/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.2794 - accuracy: 0.9091 - val_loss: 0.2599 - val_accuracy: 0.8889
# Epoch 31/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.1065 - accuracy: 0.9688 - val_loss: 0.0406 - val_accuracy: 1.0000
# Epoch 32/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 33/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 6.0660e-06 - val_accuracy: 1.0000
# Epoch 34/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.3450 - accuracy: 0.9062 - val_loss: 0.2846 - val_accuracy: 0.8889
# Epoch 35/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.0795 - accuracy: 0.9688 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 36/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 37/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.7792 - accuracy: 0.8594 - val_loss: 0.1130 - val_accuracy: 0.9444
# Epoch 38/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.0800 - accuracy: 0.9844 - val_loss: 0.0169 - val_accuracy: 1.0000
# Epoch 39/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.0520 - accuracy: 0.9697 - val_loss: 0.0172 - val_accuracy: 1.0000
# Epoch 40/45
# 11/11 [==============================] - 24s 2s/step - loss: 0.7476 - accuracy: 0.9062 - val_loss: 0.2788 - val_accuracy: 0.9444
# Epoch 41/45
# 11/11 [==============================] - 23s 2s/step - loss: 0.1013 - accuracy: 0.9844 - val_loss: 0.2049 - val_accuracy: 0.9444
# Epoch 42/45
# 11/11 [==============================] - 23s 2s/step - loss: 0.2104 - accuracy: 0.9375 - val_loss: 0.0307 - val_accuracy: 1.0000
# Epoch 43/45
# 11/11 [==============================] - 23s 2s/step - loss: 0.1753 - accuracy: 0.9375 - val_loss: 0.0354 - val_accuracy: 1.0000
# Epoch 44/45
# 11/11 [==============================] - 23s 2s/step - loss: 0.0378 - accuracy: 0.9844 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 45/45
# 11/11 [==============================] - 23s 2s/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.4362 - val_accuracy: 0.9444

# %%
fig , ax = plt.subplots(1,2, figsize=(14,5))
ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_title('model accuracy')
ax[0].set_ylabel('accuracy')
ax[0].set_xlabel('epoch')
ax[0].legend(['train', 'test'], loc='upper left')

ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('model loss')
ax[1].set_ylabel('loss')
ax[1].set_xlabel('epoch')
ax[1].legend(['train', 'test'], loc='upper left')
plt.show()

# %%
print("training_accuracy", history.history['accuracy'][-1])
print("validation_accuracy", history.history['val_accuracy'][-1])
# Out:
# training_accuracy 1.0
# validation_accuracy 0.9444444179534912
